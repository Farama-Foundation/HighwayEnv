# %%
import networkx as nx
import matplotlib.pyplot as plt

from highway_env.envs.weighted_intersection_env import WeightedIntersectionEnv

# %% [markdown]
# ## Weighted intersection environment

# %%
from highway_env.envs.weighted_intersection_env import WeightedIntersectionEnv
weighted_intersection = WeightedIntersectionEnv()
graph = weighted_intersection.road.network.graph_net
# 0: south, 1: west, 2: north, 3: east
layout = {
     'o0': [ 0,  -2],  'o1': [-6, 5],   'o2': [ 0, 12],  'o3': [6, 5],
    'ir0': [ 1,  2], 'ir1': [-3, 4],  'ir2': [-1, 8], 'ir3': [3, 6],
    'il0': [-1,  2], 'il1': [-3, 6],  'il2': [1,  8], 'il3': [3, 4], 
}
nx.draw(graph, layout, with_labels=True)

# %% [markdown]
# # Weighted roundabout environment

# %%
from highway_env.envs.weighted_roundabout_env import WeightedRoundaboutEnv
weighted_roundabout = WeightedRoundaboutEnv()
graph = weighted_roundabout.road.network.graph_net
layout = {
   'nxr': [2, 18], 'ner': [-2, 18], 'nxs': [2, 14], 'nes': [-2, 14], 'nx': [2, 10], 'ne': [-2, 10],
   'sxr': [-2, -12], 'ser': [2, -12], 'sxs': [-2, -8], 'ses': [2, -8], 'sx': [-2, -4], 'se': [2, -4],
   'exr': [15, 1], 'eer': [15, 5], 'exs': [11, 1], 'ees': [11, 5], 'ex': [7, 1], 'ee': [7, 5],
   'wxr': [-15, 5], 'wer': [-15, 1], 'wxs': [-11, 5], 'wes': [-11, 1], 'wx': [-7, 5], 'we': [-7, 1], 
}
nx.draw(graph, layout, with_labels=True)
